# %% [markdown]
# # Linear Regression Multi Variable
#
# 9) Utilize regressão linear múltipla para prever o consumo de energia com base em várias
# variáveis. Avalie o desempenho utilizando o erro médio quadrático (MSE) e o R².

# %%
# Bibliotecas necessárias:
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
# Carregando o dataset com os dados do arquivo csv gerado pelo GPT:
dataFrame = pd.read_csv('../../data/consumo_energia_sintetico.csv', encoding='utf-8')

# %%
# Visualização dos dados:
dataFrame.head(10)
# Out:
#    temperatura    umidade      vento  consumo_energia
# 0    32.961798  59.903394  16.025563       228.249141
# 1    28.792053  69.669957  16.720909       227.535641
# 2    33.953210  70.435109  18.509879       262.579565
# 3    39.701358  65.922961  18.409689       281.227350
# 4    28.162373  72.216440  10.080938       254.792917
# 5    28.162481  77.767113  11.587578       262.757168
# 6    40.070298  92.319234  16.564199       348.074007
# 7    34.739553  75.514066  16.559920       269.130423
# 8    26.617078  76.328720  16.564242       241.521080
# 9    33.262857  73.069064  27.997129       226.439100

# %%
# Separando as features e a classe para o modelo de regressão linear múltiplo:
features, classe = dataFrame.drop(['consumo_energia'], axis=1), dataFrame['consumo_energia']

# %%
# Seprando os conjuntos de dados para treinamento e validação:
features_treinamento, features_validacao, classe_treinamento, classe_validacao = train_test_split(features, classe, test_size=0.30)

# %%
# Treinando o modelo de Regressão Linear:
modelo_RL = LinearRegression()
modelo_RL.fit(features, classe)
# Out:
# LinearRegression()

# %%
# Realizando a predição com os dados de validação:
classe_predicao = modelo_RL.predict(features_validacao)

# %%
# Métrica do MSE:
print(f"Média Quadrática de Erro: {mean_squared_error(classe_validacao, classe_predicao):.2f}")
# Out:
# Média Quadrática de Erro: 63.38

# %%
# Métrica do R2:
print(f"R² Score: {r2_score(classe_validacao, classe_predicao):.2f}")
# Out:
# R² Score: 0.93
